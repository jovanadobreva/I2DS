# %% [markdown]
# <a href="https://colab.research.google.com/github/jovanadobreva/I2DS/blob/main/Exercise%206/Exercise6_exam_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задача 1

# %% [markdown]
# #Прв дел

# %% [markdown]
# #Симнете ги податочните множества локално
# изврши ги следните два блока

# %%
# !gdown --id 1-38wf-K-FU9AyyyLF8Ke8e8zYoYYc8vV
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1-38wf-K-FU9AyyyLF8Ke8e8zYoYYc8vV
# To: /content/time_mk_bitcoin_3.csv
# 100% 16.0k/16.0k [00:00<00:00, 43.6MB/s]

# %%
# !gdown --id 1j2Qt86iWn9W-yw17VEYMUzxBj27hHSi0
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1j2Qt86iWn9W-yw17VEYMUzxBj27hHSi0
# To: /content/BTC-USD-3.csv
# 100% 2.04k/2.04k [00:00<00:00, 9.16MB/s]

# %% [markdown]
# #Спој ги двете податочни множества

# %%
import pandas as pd

df_btc=pd.read_csv('/content/BTC-USD-3.csv')
df_timemk=pd.read_csv('/content/time_mk_bitcoin_3.csv')

# %%
df_btc.head()
# Out:
#        Date         Open        Close
# 0  01-01-22  46311.74609  47686.81250
# 1  02-01-22  47680.92578  47345.21875
# 2  03-01-22  47343.54297  46458.11719
# 3  04-01-22  46458.85156  45897.57422
# 4  05-01-22  45899.35938  43569.00391

# %%
df_timemk
# Out:
#         Date          Source  \
# 0   01-03-22         Локално
# 1   01-03-22    Н.Македонија
# 2   01-03-22      Вечер Прес
# 3   01-03-22  Слободен Печат
# 4   01-03-22   Банкарство.мк
# ..       ...             ...
# 95  09-02-22          Фактор
# 96  09-02-22           Курир
# 97  09-02-22           Фокус
# 98  09-02-22           А1 On
# 99  09-02-22        24 Вести
#
#                                                 Title
# 0   Биткоинот целосно се опорави од шокот предизви...
# 1   Украинската криза го промовираше биткоинот во ...
# 2   Најголемата крипто берза не сака да ја блокира...
# 3   ВИДЕО | Гошевски: Прва Светска крипто-војна – ...
# 4   Најголемата крипто берза не сака да ја блокира...
# ..                                                ...
# 95  НА КРАДЦИТЕ ИМ СЕ ЗАКАНУВА 20 ГОДИНИ ЗАТВОР: К...
# 96  САД:Запленети 94.000 биткоини украдени во 2016...
# 97  Во САД запленети 94.000 биткоини украдени во 2...
# 98  Американското Министерство за правда заплени н...
# ...

# %%
df=df_btc.set_index('Date').join(df_timemk.set_index('Date')).reset_index()

# %%
df
# Out:
#          Date         Open        Close        Source  \
# 0    01-01-22  46311.74609  47686.81250           NaN
# 1    01-02-22  38481.76563  38743.27344           NaN
# 2    01-03-22  43194.50391  44354.63672       Локално
# 3    01-03-22  43194.50391  44354.63672  Н.Македонија
# 4    01-03-22  43194.50391  44354.63672    Вечер Прес
# ..        ...          ...          ...           ...
# 137  28-02-22  37706.00000  43193.23438          Пари
# 138  28-02-22  37706.00000  43193.23438        Фактор
# 139  29-01-22  37780.71484  38138.17969           NaN
# 140  30-01-22  38151.91797  37917.60156           NaN
# 141  31-01-22  37920.28125  38483.12500           NaN
#
#                                                  Title
# 0                                                  NaN
# 1                                                  NaN
# 2    Биткоинот целосно се опорави од шокот предизви...
# 3    Украинската криза го промовираше биткоинот во ...
# ...

# %% [markdown]
# #Направи визуелизација на таргет колоната

# %%
df.Open.hist()
# Out:
# <Axes: >

# %%
df.Open.plot.area()
# Out:
# <Axes: >

# %%
df.Open.unique()
# Out:
# array([46311.74609, 38481.76563, 43194.50391, 47680.92578, 38743.71484,
#        47343.54297, 36944.80469, 46458.85156, 37149.26563, 45899.35938,
#        41501.48047, 43565.51172, 41441.12109, 43153.57031, 42406.78125,
#        41561.46484, 43854.65234, 41734.72656, 44096.70313, 41910.23047,
#        44347.80078, 41819.50781, 43571.12891, 42742.17969, 42412.30078,
#        43946.74219, 42236.56641, 42598.87109, 42157.39844, 43101.89844,
#        42586.46484, 43172.03906, 44578.27734, 43118.12109, 43937.07031,
#        42250.07422, 40552.13281, 42374.03906, 40026.02344, 41744.02734,
#        40118.10156, 40699.60547, 38423.21094, 36471.58984, 37068.76953,
#        35047.35938, 38285.28125, 36275.73438, 37278.56641, 36654.80469,
#        38333.74609, 36950.51563, 39213.08203, 36841.87891, 39098.69922,
#        37128.44531, 37706.     , 37780.71484, 38151.91797, 37920.28125])

# %% [markdown]
# #Изврши статистика за колоните

# %%
df.min()
# Out:
# <ipython-input-15-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# Date        01-01-22
# Open     35047.35938
# Close       35030.25
# dtype: object

# %%
df.max()
# Out:
# <ipython-input-16-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# Date        31-01-22
# Open     47680.92578
# Close     47686.8125
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-17-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Open     40569.029078
# Close    40842.843312
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-18-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Open     39213.082030
# Close    40076.566405
# dtype: float64

# %% [markdown]
# #Претпроцесирај ги текстуалните податоци

# %%
from sklearn.preprocessing import LabelEncoder

encoder=LabelEncoder()
tmp=encoder.fit_transform(df.Source)

# %%
len(encoder.classes_)-1
# Out:
# 40

# %%
import numpy as np
lista=[]
for i in tmp:
  if i==40:
    lista.append(np.nan)
  else:
    lista.append(i)

# %%
df['Source']=lista

# %%
df['Title']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2      Биткоинот целосно се опорави од шокот предизви...
# 3      Украинската криза го промовираше биткоинот во ...
# 4      Најголемата крипто берза не сака да ја блокира...
#                              ...
# 137    „ПРВАТА СВЕТСКА КРИПТО ВОЈНА“ е војната во Укр...
# 138    ДОВОЛЕН БЕШЕ САМО ЕДЕН ПОВИК: Еве колку долари...
# 139                                                  NaN
# 140                                                  NaN
# 141                                                  NaN
# Name: Title, Length: 142, dtype: object

# %%
tmp=encoder.fit_transform(df['Title'])

# %%
len(encoder.classes_)-1
# Out:
# 80

# %%
import numpy as np
lista=[]
for i in tmp:
  if i==80:
    lista.append(np.nan)
  else:
    lista.append(i)

# %%
df['Title']=lista

# %%
df.Source.hist()
# Out:
# <Axes: >

# %%
df.Title.hist()
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# Date       0
# Open       0
# Close      0
# Source    42
# Title     42
# dtype: int64

# %%
from sklearn.impute import KNNImputer

KNNImputer = KNNImputer(n_neighbors=3)
df['Title'] = KNNImputer.fit_transform(df['Title'].to_numpy().reshape(-1,1))
df['Source'] = KNNImputer.fit_transform(df['Source'].to_numpy().reshape(-1,1))

# %%
df
# Out:
#          Date         Open        Close  Source  Title
# 0    01-01-22  46311.74609  47686.81250    20.3  40.04
# 1    01-02-22  38481.76563  38743.27344    20.3  40.04
# 2    01-03-22  43194.50391  44354.63672    21.0  18.00
# 3    01-03-22  43194.50391  44354.63672    25.0  72.00
# 4    01-03-22  43194.50391  44354.63672    13.0  41.00
# ..        ...          ...          ...     ...    ...
# 137  28-02-22  37706.00000  43193.23438    28.0  78.00
# 138  28-02-22  37706.00000  43193.23438    37.0  31.00
# 139  29-01-22  37780.71484  38138.17969    20.3  40.04
# 140  30-01-22  38151.91797  37917.60156    20.3  40.04
# 141  31-01-22  37920.28125  38483.12500    20.3  40.04
#
# [142 rows x 5 columns]

# %% [markdown]
# #Подели го податочното множество за тренирање и тестирање

# %%
Y=df['Open']
X= df[['Close','Source','Title']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1)

# %% [markdown]
# #Одреди кои ќе ти бидат влезни податоци и објасни зошто

# %% [markdown]
# Тука внеси го објаснувањето

# %% [markdown]
# #Изгради модел и тренирај го

# %% [markdown]
# Linearna regresija

# %%
from sklearn.kernel_ridge import KernelRidge

model=KernelRidge()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from numpy import absolute

k_fold=RepeatedKFold(n_splits=5, n_repeats=10, random_state=None)
scores=cross_val_score(model, X_train, Y_train, cv=k_fold, scoring='neg_mean_absolute_error')
abs(scores.mean())
# Out:
# 936.9918439284401

# %%
model.fit(X_train,Y_train)
# Out:
# KernelRidge()

# %% [markdown]
# Decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(criterion='absolute_error',max_depth=4,min_samples_split=5,min_samples_leaf=5)

# %%
regressor.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_depth=4,
#                       min_samples_leaf=5, min_samples_split=5)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# #Тестирај го моделот со помош на соодветна метрика за евалуација

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.5040058792303967

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# 1053.6098960833328

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(regressor, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True,feature_names = X.columns,class_names=df.Open.unique())
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# #Bтор дел
# Изврши web crawling со цел да го добиеш истото податочно множество како time_mk_bitcoin_3.csv

# %% [markdown]
# #Втора задача

# %%
df=pd.read_csv('/content/nasa_stars.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Temperature', 'L', 'R', 'A_M', 'Color',
#        'Spectral_Class', 'Type'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'],axis=1,inplace=True)

# %%
df.Temperature.hist()
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# Temperature       15
# L                 22
# R                 16
# A_M               12
# Color              0
# Spectral_Class     0
# Type               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature     225 non-null    float64
#  1   L               218 non-null    float64
#  2   R               224 non-null    float64
#  3   A_M             228 non-null    float64
#  4   Color           240 non-null    int64
#  5   Spectral_Class  240 non-null    int64
#  6   Type            240 non-null    int64
# dtypes: float64(4), int64(3)
# memory usage: 13.2 KB

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
df.Temperature.hist()
# Out:
# <Axes: >

# %%
df['A_M'].hist()
# Out:
# <Axes: >

# %%
df['L'].hist()
# Out:
# <Axes: >

# %%
df['R'].hist()
# Out:
# <Axes: >

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy='median')

# %%
df['R']=imp.fit_transform(df['R'].to_numpy().reshape(-1,1))
df['L']=imp.fit_transform(df['L'].to_numpy().reshape(-1,1))
df['Temperature']=imp.fit_transform(df['Temperature'].to_numpy().reshape(-1,1))

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
it_imp=IterativeImputer()
df['A_M']=it_imp.fit_transform(df['A_M'].to_numpy().reshape(-1,1))

# %%
df
# Out:
#      Temperature              L          R        A_M  Color  Spectral_Class  \
# 0         5936.0       0.119000     0.7350   4.212566      8               5
# 1         3042.0       0.000500     0.1542  16.600000      8               5
# 2         2600.0       0.000300     0.1020  18.700000      8               5
# 3         2800.0       0.000200     0.1600  16.650000      8               5
# 4         1939.0       0.000138     0.1030  20.060000      8               5
# ..           ...            ...        ...        ...    ...             ...
# 235      38940.0  374830.000000  1356.0000  -9.930000      0               6
# 236      30839.0  834042.000000  1194.0000 -10.630000      0               6
# 237       8829.0  537493.000000  1423.0000 -10.730000      9               0
# 238       5936.0  404940.000000  1112.0000 -11.230000      9               0
# 239      37882.0  294903.000000  1783.0000  -7.800000      0               6
#
#      Type
# 0       0
# 1       0
# ...

# %%
X=df.iloc[:,:-1]
Y=df['Type']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
df.Type.unique()
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=10,min_samples_leaf=10)

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=10)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import f1_score,accuracy_score,classification_report,recall_score

# %%
f1_score(Y_test,y_pred,average='micro')
# Out:
# 0.9375

# %%
f1_score(Y_test,y_pred,average='macro')
# Out:
# 0.9156565656565657

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00         6
#            3       0.57      1.00      0.73         4
#            4       1.00      0.88      0.93         8
#            5       1.00      1.00      1.00        12
#
#     accuracy                           0.94        48
#    macro avg       0.93      0.93      0.92        48
# weighted avg       0.96      0.94      0.94        48
