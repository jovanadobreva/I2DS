# %% [markdown]
# <a href="https://colab.research.google.com/github/jovanadobreva/I2DS/blob/main/Exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset from: https://www.kaggle.com/datasets/piterfm/2022-ukraine-russian-war

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/russia_losses_equipment.csv')

# %%
df.head(10)
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 1  2022-02-26    3        27          26   146  706               49    4
# 2  2022-02-27    4        27          26   150  706               50    4
# 3  2022-02-28    5        29          29   150  816               74   21
# 4  2022-03-01    6        29          29   198  846               77   24
# 5  2022-03-02    7        30          31   211  862               85   40
# 6  2022-03-03    8        30          31   217  900               90   42
# 7  2022-03-04    9        33          37   251  939              105   50
# 8  2022-03-05   10        39          40   269  945              105   50
# 9  2022-03-06   11        44          48   285  985              109   50
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0          100.0       60.0      0           2                      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       598 non-null    object
#  1   day                        598 non-null    int64
#  2   aircraft                   598 non-null    int64
#  3   helicopter                 598 non-null    int64
#  4   tank                       598 non-null    int64
#  5   APC                        598 non-null    int64
#  6   field artillery            598 non-null    int64
#  7   MRL                        598 non-null    int64
#  8   military auto              65 non-null     float64
#  9   fuel tank                  65 non-null     float64
#  10  drone                      598 non-null    int64
#  11  naval ship                 598 non-null    int64
#  12  anti-aircraft warfare      598 non-null    int64
# ...

# %%
df.isna().sum()
# Out:
# date                           0
# day                            0
# aircraft                       0
# helicopter                     0
# tank                           0
# APC                            0
# field artillery                0
# MRL                            0
# military auto                533
# fuel tank                    533
# drone                          0
# naval ship                     0
# anti-aircraft warfare          0
# special equipment             19
# mobile SRBM system           562
# greatest losses direction    395
# vehicles and fuel tanks       65
# cruise missiles               65
# submarines                   566
# dtype: int64

# %%
df['date']
# Out:
# 0      2022-02-25
# 1      2022-02-26
# 2      2022-02-27
# 3      2022-02-28
# 4      2022-03-01
#           ...
# 593    2023-10-11
# 594    2023-10-12
# 595    2023-10-13
# 596    2023-10-14
# 597    2023-10-15
# Name: date, Length: 598, dtype: object

# %%
df.min()
# Out:
# <ipython-input-15-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# date                       2022-02-25
# day                                 2
# aircraft                           10
# helicopter                          7
# tank                               80
# APC                               516
# field artillery                    49
# MRL                                 4
# military auto                   100.0
# fuel tank                        60.0
# drone                               0
# naval ship                          2
# anti-aircraft warfare               0
# special equipment                10.0
# mobile SRBM system                2.0
# vehicles and fuel tanks        1796.0
# ...

# %%
df['submarines'].max()
# Out:
# 1.0

# %%
df['submarines'].unique()
# Out:
# array([nan,  1.])

# %%
df.median()
# Out:
# <ipython-input-19-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# day                         300.5
# aircraft                    281.5
# helicopter                  266.5
# tank                       2998.5
# APC                        5976.5
# field artillery            1966.0
# MRL                         411.0
# military auto              1178.0
# fuel tank                    73.0
# drone                      1684.0
# naval ship                   16.0
# anti-aircraft warfare       212.0
# special equipment           180.0
# mobile SRBM system            4.0
# vehicles and fuel tanks    4932.0
# cruise missiles             749.0
# submarines                    1.0
# dtype: float64

# %%
len(df['aircraft'].unique())
# Out:
# 149

# %%
df['helicopter'].hist(bins=5)
# Out:
# <Axes: >

# %%
tmp_df = df.groupby(['aircraft']).count()

# %%
tmp_df
# Out:
#           date  day  helicopter  tank  APC  field artillery  MRL  \
# aircraft
# 10           1    1           1     1    1                1    1
# 27           2    2           2     2    2                2    2
# 29           2    2           2     2    2                2    2
# 30           2    2           2     2    2                2    2
# 33           1    1           1     1    1                1    1
# ...        ...  ...         ...   ...  ...              ...  ...
# 313         10   10          10    10   10               10   10
# 314         22   22          22    22   22               22   22
# 315        102  102         102   102  102              102  102
# 316          5    5           5     5    5                5    5
# 317          2    2           2     2    2                2    2
#
#           military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# aircraft
# 10                    1          1      1           1                      1
# ...

# %%
tmp_df = tmp_df.iloc[:,:1]

# %%
tmp_df.columns = ['count']

# %%
tmp_df
# Out:
#           count
# aircraft
# 10            1
# 27            2
# 29            2
# 30            2
# 33            1
# ...         ...
# 313          10
# 314          22
# 315         102
# 316           5
# 317           2
#
# [149 rows x 1 columns]

# %%
tmp_df.hist()
# Out:
# array([[<Axes: title={'center': 'count'}>]], dtype=object)

# %%
fig  = df.plot.bar(x='date',y='drone')

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

# %%
.xticks(rotation=90)
# Out:
# <Axes: xlabel='date'>
